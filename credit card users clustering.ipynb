# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
credit_data = pd.read_csv(r"C:\Users\moham\Downloads\CC GENERAL (2).csv")
credit_data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
#duplicate values
credit_data.duplicated().sum()
# Out:
# 0

# %%
#missing values
credit_data.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
credit_data.isnull().mean()*100
# Out:
# CUST_ID                             0.000000
# BALANCE                             0.000000
# BALANCE_FREQUENCY                   0.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.011173
# PAYMENTS                            0.000000
# MINIMUM_PAYMENTS                    3.497207
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              0.000000
# dtype: float64

# %%
credit_data.isnull().sum()/len(credit_data)*100
# Out:
# CUST_ID                             0.000000
# BALANCE                             0.000000
# BALANCE_FREQUENCY                   0.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.011173
# PAYMENTS                            0.000000
# MINIMUM_PAYMENTS                    3.497207
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              0.000000
# dtype: float64

# %%
#checking the data on a granular level
for i in credit_data.columns:
    print("********************",i,"*********************************")
    print()
    print(set(credit_data[i].tolist()))
# Out:
# ******************** CUST_ID *********************************
#
# ...

# %%
credit_data.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
## filling missing values
credit_data["MINIMUM_PAYMENTS"].dtype
# Out:
# dtype('float64')

# %%
credit_data["CREDIT_LIMIT"].dtype
# Out:
# dtype('float64')

# %%
#seperating the the object type and numeric type for imputation
credit_data_obj = credit_data.select_dtypes(include = "object")
credit_data_obj

credit_data_numeric = credit_data.select_dtypes(exclude = "object")
credit_data_numeric
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
##
from sklearn.impute import SimpleImputer
credit_data_numeric_impute = SimpleImputer(strategy = "median").fit_transform(credit_data_numeric)
credit_data_numeric_impute = pd.DataFrame(credit_data_numeric_impute , columns = credit_data_numeric.columns )
credit_data_numeric_impute
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
credit_data_numeric_impute.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
# merging both the dataframes now
credit_Data_final = pd.concat([credit_data_obj,credit_data_numeric_impute],axis=1)
credit_Data_final
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
# dropping the cust id column
credit_Data_final.drop("CUST_ID" ,axis=1 ,inplace=True)
credit_Data_final
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
##feature scaling
from sklearn.preprocessing import StandardScaler
credit_data_scaled = StandardScaler().fit_transform(credit_Data_final)
credit_data_scaled = pd.DataFrame(credit_data_scaled , columns = credit_Data_final.columns )
credit_data_scaled
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    -0.731989          -0.249434  -0.424900         -0.356934
# 1     0.786961           0.134325  -0.469552         -0.356934
# 2     0.447135           0.518084  -0.107668          0.108889
# 3     0.049099          -1.016953   0.232058          0.546189
# 4    -0.358775           0.518084  -0.462063         -0.347294
# ...        ...                ...        ...               ...
# 8945 -0.737950           0.518084  -0.333293         -0.356934
# 8946 -0.742423           0.518084  -0.329136         -0.356934
# 8947 -0.740398          -0.185477  -0.401965         -0.356934
# 8948 -0.745174          -0.185477  -0.469552         -0.356934
# 8949 -0.572575          -0.889033   0.042146          0.301732
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                  -0.349079     -0.466786            -0.806490
# 1                  -0.454576      2.605605            -1.221758
# ...

# %%
#lets do the clusteringusing aggleromwerative method
from scipy.cluster.hierarchy import linkage, dendrogram
import scipy.cluster.hierarchy  as sch

plt.figure(figsize=(15,14))
z_linkage = linkage(credit_data_scaled,method='ward')
z_linkage
dendro = dendrogram(z_linkage , color_threshold=10,truncate_mode='lastp',p=60)
dendro
plt.show()

# %%
cluster_18 = sch.fcluster(z_linkage,18,criterion='maxclust')
cluster_18.tolist()
# Out:
# [18,
#  10,
#  17,
#  14,
#  18,
#  18,
#  6,
#  2,
#  18,
#  14,
#  2,
#  18,
#  2,
#  2,
#  18,
#  11,
#  12,
#  14,
#  17,
#  16,
#  16,
#  8,
#  14,
#  9,
#  10,
#  2,
#  18,
#  2,
#  10,
#  18,
#  11,
#  2,
#  11,
#  17,
#  16,
#  18,
#  11,
#  3,
#  11,
#  14,
#  18,
#  4,
#  11,
#  18,
#  3,
#  18,
#  14,
#  10,
#  1,
#  18,
#  9,
#  17,
#  18,
#  13,
#  14,
#  17,
#  10,
#  3,
#  18,
#  11,
#  17,
#  18,
#  12,
#  14,
#  2,
#  17,
#  12,
#  18,
#  17,
#  17,
#  11,
#  9,
#  12,
#  18,
#  18,
#  11,
#  17,
#  2,
#  16,
#  11,
#  18,
#  14,
#  14,
#  1,
#  3,
#  1,
#  4,
#  4,
#  11,
#  10,
#  8,
#  4,
#  18,
#  18,
#  17,
#  18,
#  17,
#  10,
#  14,
#  14,
#  18,
#  14,
#  3,
#  14,
#  18,
#  10,
#  2,
#  9,
#  18,
#  9,
#  2,
#  18,
#  4,
#  11,
#  1,
#  2,
#  2,
#  18,
#  14,
#  18,
#  4,
#  17,
#  8,
#  18,
#  11,
#  6,
#  12,
#  2,
#  11,
#  14,
#  14,
#  3,
#  14,
#  9,
#  2,
#  17,
#  8,
#  4,
#  7,
#  17,
#  17,
#  18,
#  10,
#  11,
#  3,
#  18,
#  2,
#  18,
#  17,
# ...

# %%
credit_Data_final["clusters18_dendero"] = cluster_18

# %%
credit_Data_final
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
## doing the clistering using kmeans
from sklearn.cluster import KMeans
kmean_clustering = KMeans(n_clusters=18,random_state=47).fit(credit_data_scaled)
kmean_clustering
# Out:
# KMeans(n_clusters=18, random_state=47)

# %%
kmean_clustering.labels_.tolist()
# Out:
# [6,
#  4,
#  0,
#  6,
#  6,
#  5,
#  15,
#  5,
#  6,
#  7,
#  5,
#  6,
#  5,
#  5,
#  6,
#  13,
#  16,
#  7,
#  5,
#  5,
#  5,
#  15,
#  5,
#  17,
#  4,
#  5,
#  6,
#  5,
#  1,
#  6,
#  13,
#  5,
#  13,
#  0,
#  12,
#  6,
#  13,
#  10,
#  13,
#  17,
#  4,
#  0,
#  6,
#  6,
#  10,
#  6,
#  16,
#  4,
#  9,
#  6,
#  1,
#  0,
#  6,
#  0,
#  5,
#  6,
#  4,
#  10,
#  6,
#  13,
#  6,
#  6,
#  4,
#  7,
#  5,
#  6,
#  16,
#  4,
#  5,
#  6,
#  5,
#  8,
#  16,
#  6,
#  6,
#  5,
#  0,
#  5,
#  6,
#  13,
#  5,
#  7,
#  7,
#  2,
#  10,
#  9,
#  1,
#  1,
#  6,
#  13,
#  10,
#  1,
#  6,
#  6,
#  6,
#  6,
#  0,
#  4,
#  7,
#  16,
#  16,
#  5,
#  10,
#  7,
#  6,
#  4,
#  5,
#  1,
#  5,
#  17,
#  5,
#  6,
#  10,
#  13,
#  9,
#  5,
#  2,
#  4,
#  7,
#  4,
#  15,
#  6,
#  10,
#  6,
#  13,
#  15,
#  16,
#  5,
#  13,
#  7,
#  7,
#  5,
#  7,
#  17,
#  5,
#  6,
#  10,
#  5,
#  3,
#  0,
#  6,
#  6,
#  4,
#  13,
#  15,
#  6,
#  5,
#  6,
#  5,
#  5,
#  13,
#  10,
#  2,
#  3,
#  2,
#  7,
#  1,
#  6,
#  15,
# ...

# %%
credit_Data_final["k_means_clusters18"] = kmean_clustering.labels_
credit_Data_final
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...
